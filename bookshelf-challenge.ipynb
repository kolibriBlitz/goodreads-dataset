# %% [markdown]
# # Setup

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

import datetime #for data type changes
import matplotlib as mpl #for visualizations
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns 
import sklearn as sk #for machine learning analysis methods
import random #for random gen

print('All done!')
# Out:
# /kaggle/input/book-reviews/goodreads_data_dictionary.csv
# /kaggle/input/book-reviews/goodreads_reviews.csv
# /kaggle/input/book-reviews/goodreads_works.csv
# All done!

# %%
from IPython.core.interactiveshell import InteractiveShell 
InteractiveShell.ast_node_interactivity = "all"
#to allow multiple outputs from one code cell

# %% [markdown]
# # Import
#
# Data connected. Now to read it into some data frame variables!

# %%
book_list=pd.read_csv("/kaggle/input/book-reviews/goodreads_works.csv") #index_col='work_id' added after taking more kaggle courses, then removed because it screws everything up downstream
#reviews=pd.read_csv("/kaggle/input/book-reviews/goodreads_reviews.csv")

# %% [markdown]
# **New Error Unlocked**
# /tmp/ipykernel_36/3857527195.py:2: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   reviews=pd.read_csv("/kaggle/input/book-reviews/goodreads_reviews.csv")

# %% [markdown]
# Pulling the data dictionary into a data frame to get an idea of what columns might be throwing mixed types. Also checking the stats of Kaggle's data model pages. That did not shed any light on things...

# %%
FAQ=pd.read_csv("/kaggle/input/book-reviews/goodreads_data_dictionary.csv")
FAQ
#low_memory=False #did not help on this line
reviews=pd.read_csv("/kaggle/input/book-reviews/goodreads_reviews.csv",low_memory=False) #pandas documentation is not an easy read, so this was a natual second step
reviews.work_id.value_counts()
# Out:
#       Table                      Field  \
# 0     works                    work_id
# 1     works                       isbn
# 2     works                     isbn13
# 3     works             original_title
# 4     works                     author
# 5     works  original_publication_year
# 6     works                  num_pages
# 7     works                description
# 8     works                     genres
# 9     works                  image_url
# 10    works              reviews_count
# 11    works         text_reviews_count
# 12    works             5_star_ratings
# 13    works             4_star_ratings
# 14    works             3_star_ratings
# 15    works             2_star_ratings
# 16    works             1_star_ratings
# 17    works              ratings_count
# 18    works                 avg_rating
# 19    works              similar_books
# 20  reviews                  review_id
# 21  reviews                    user_id
# 22  reviews                    work_id
# 23  reviews                 started_at
# 24  reviews                    read_at
# 25  reviews                 date_added
# 26  reviews                     rating
# 27  reviews                review_text
# 28  reviews                    n_votes
# 29  reviews                 n_comments
#
#                                           Description
# 0   Unique identifier for the book (work) in the d...
# 1   The 10-digit International Standard Book Numbe...
# 2   The 13-digit International Standard Book Numbe...
# 3   The original title of the book, in its origina...
# 4                  Name of the book’s primary author.
# 5                  Year the work was first published.
# 6   Total number of pages in the work’s primary ed...
# 7   Summary or synopsis of the book, typically fro...
# 8   Comma-separated list of genres associated with...
# 9                 URL link to the book’s cover image.
# 10  Total number of reviews for the work, based on...
# 11  Number of written (text) reviews for the work,...
# 12    Number of 5-star ratings the work has received.
# 13    Number of 4-star ratings the work has received.
# 14    Number of 3-star ratings the work has received.
# 15    Number of 2-star ratings the work has received.
# 16    Number of 1-star ratings the work has received.
# 17  Total number of ratings the work has received ...
# 18  Average rating for the work, typically a float...
# 19  Comma-separated list of work IDs for books tha...
# 20                 Unique identifier for each review.
# 21  Unique identifier for the user who submitted t...
# 22  ID of the book (work) being reviewed (foreign ...
# 23  Date the user marked as when they started read...
# 24  Date the user marked as when they finished rea...
# 25            Date the review was added to Goodreads.
# 26         Number of stars (1–5) given in the review.
# 27  Full text of the user’s written review, where ...
# 28  Number of "helpful" or "likes" votes the revie...
# 29  Number of comments left by other users on the ...
# work_id
# 16827462    3208
# 13155899    3129
# 2792775     2766
# 48765776    2418
# 21861351    2393
#             ...
# 50441204       8
# 2754856        8
# 18419055       8
# 375196         8
# 26742752       8
# Name: count, Length: 13525, dtype: int64

# %% [markdown]
# ## Data Exploration - Reviews
# First let's see which columns had the mixed types...

# %%
dtypes=pd.DataFrame({'review_id': reviews.review_id.dtype,'user_id': reviews.user_id.dtype,'work_id':reviews.work_id.dtype,'started_at':reviews.work_id.dtype,'read_at':reviews.work_id.dtype,'date_added':reviews.work_id.dtype,'rating':reviews.work_id.dtype,'review_text':reviews.work_id.dtype,'n_votes':reviews.work_id.dtype,'n_comments':reviews.work_id.dtype},index=[0])
dtypes
reviews.dtypes

# %% [markdown]
# Well, I am going to guess that the three columns being the issue are 'started_at', 'read_at' and 'date_added' because I would think they should be date/time fields, yet they are reporting as int.
#
# ***Oh my god! I went back to a different lesson in Pandas and found the simple way to get the types of the columns.***
# 😫😲 Now I am embarrassed, but *silver lining* I practiced creating data frames and now I will never forget this command exists! I came up here first because I just copied and pasted the code from the lesson (reviews.dtypes) so I didn't know it existed before going and working on the book_list table.
#
# Next, I am going to look at value counts per column and nulls.

# %%
reviews.review_id.value_counts()
reviews.review_id.isnull().sum()
reviews.user_id.value_counts()
reviews.user_id.isnull().sum()
reviews.work_id.value_counts()
reviews.work_id.isnull().sum()
reviews.started_at.value_counts()
reviews.started_at.isnull().sum()
reviews.read_at.value_counts()
reviews.read_at.isnull().sum()
reviews.date_added.value_counts()
reviews.date_added.isnull().sum()
reviews.rating.value_counts()
reviews.rating.isnull().sum()
reviews.review_text.value_counts()
reviews.review_text.isnull().sum()
reviews.n_votes.value_counts()
reviews.n_votes.isnull().sum()
reviews.n_comments.value_counts()
reviews.n_comments.isnull().sum()

# %% [markdown]
# * review_id: all values unique, no nulls
# * user_id: 18800 unique values, no nulls
# * work_id: 13525 unique values, no nulls
# * started_at: 3797 unique values, 347495 nulls
# * read_at: 5868 unique values, 112122 nulls
# * date_added: 3919 unique values, no nulls
# * rating: 5 unique values, 37318 nulls
# * review_text:1130794 unique values, no nulls
# * n_votes: 605 unique values, no nulls
# * n_comments: 228 unique values, no nulls

# %% [markdown]
# I wonder if the null ratings have reviews. Perhaps I can impute a rating based on the review. There are 37318 though, so if I choose to impute, I'd need to use a function that has a reliable filter, e.g., if review contains '!' & 'good' = 5.0, if review contains 'good' = 4.0, etc.

# %%
reviews.loc[reviews.rating.isnull()==True]

# %% [markdown]
# Based on these results, there doesn't seem to be a reliable way to impute an accurate rating. Also, some reviews aren't indicative of the essence of the book.

# %% [markdown]
# Checking some of the quantifiable options...

# %%
round(reviews.describe(),2)
reviews.n_votes.max()
reviews.n_votes.min()
reviews.n_votes.mean()
reviews.n_votes.median()
reviews.rating.mean()
37318/1143887 #percent of ratings with null

# %% [markdown]
# n_votes may or may not be useful as it's heavily skewed...may give less weight if used

# %% [markdown]
# ## Data Exploration - Works

# %%
book_list.head()
# Out:
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
#     work_id        isbn        isbn13         original_title  \
# 0   2919130  1416534601  9.781417e+12              Nocturnes
# 1  52087333         NaN           NaN              Draw Play
# 2   1649583  1416505520  9.781417e+12  Citizen of the Galaxy
# 3    688299  0060541830  9.780061e+12                  Congo
# 4   3464264  0451528824  9.780452e+12   Anne of Green Gables
#
#                author  original_publication_year  num_pages  \
# 0       John Connolly                     2004.0        NaN
# 1           Tia Lewis                     2016.0        NaN
# 2  Robert A. Heinlein                     1957.0        NaN
# 3    Michael Crichton                     1980.0        NaN
# 4     L.M. Montgomery                     1908.0        NaN
#
#                                          description  \
# 0                                                NaN
# 1  Jake:\nI can't believe my coach assigned me a ...
# 2  In a distant galaxy, the atrocity of slavery w...
# 3  Deep in the African rain forest, near the lege...
# 4  Everyone's favorite redhead, the spunky Anne S...
#
#                                               genres  \
# 0  fiction, fantasy, paranormal, mystery, thrille...
# 1                                   romance, fiction
# 2  fiction, young-adult, fantasy, paranormal, chi...
# 3  fiction, mystery, thriller, crime, fantasy, pa...
# 4  fiction, young-adult, children, history, histo...
#
#                                            image_url  reviews_count  \
# 0  https://s.gr-assets.com/assets/nophoto/book/11...           8820
# 1  https://s.gr-assets.com/assets/nophoto/book/11...           2482
# 2  https://s.gr-assets.com/assets/nophoto/book/11...          16506
# 3  https://s.gr-assets.com/assets/nophoto/book/11...         170916
# 4  https://s.gr-assets.com/assets/nophoto/book/11...         743392
#
#    text_reviews_count  5_star_ratings  4_star_ratings  3_star_ratings  \
# 0                 338            1118            1601            1029
# 1                 204             204             353             274
# 2                 447            3539            4351            2863
# 3                1633           25081           45775           48505
# 4               14586          272952          161856           81578
#
#    2_star_ratings  1_star_ratings  ratings_count  avg_rating similar_books
# 0             190              58           3996         3.9           NaN
# 1              77              29            937         3.7           NaN
# 2             444              53          11250         4.0           NaN
# 3           14001            2926         136288         3.6           NaN
# 4           19933            9099         545418         4.2           NaN

# %% [markdown]
# Well, I don't think I need to keep image_url for my purposes. I also want to get a count on nulls in isbn and isbn13 because that data should be available, but the work involved if it's alot...
# Kaggle didn't throw a data type error for this table, but I want to confirm what the are.

# %%
book_list.num_pages.isnull().sum()
# Out:
# 730

# %%
#book_list.describe()
data_types=pd.DataFrame({'work_id':book_list.work_id.dtype,'isbn':book_list.isbn.dtype,'isbn13':book_list.isbn13.dtype,'orig_pub_yr':book_list.original_publication_year.dtype,'num_pages':book_list.num_pages.dtype,'description':book_list.description.dtype,'genres':book_list.genres.dtype,'num_reviews':book_list.reviews_count.dtype,'num_text_reviews':book_list.text_reviews_count.dtype,'num_5stars':book_list['5_star_ratings'].dtype,'num_4stars':book_list['4_star_ratings'].dtype,'num_3stars':book_list['3_star_ratings'].dtype,'num_2stars':book_list['2_star_ratings'].dtype,'num_1stars':book_list['1_star_ratings'].dtype, 'num_ratings': book_list.ratings_count.dtype,'avg_rating':book_list.avg_rating.dtype,'similar_books':book_list.similar_books.dtype},index=[0])
data_types
#book_list.5_star_ratings #invalid
#book_list['5_star_ratings'] #valid
#book_list.description[1]
book_list.dtypes

# %% [markdown]
# That was fun figuring out the correct way to select a column that starts with a digit!
# Also, I wish I knew about how you can call dtypes on the data frame before...it's nice not having to horizontally scroll.
# Type recommendations have been recorded and now we move on the the null testing...

# %% [markdown]
# I added in this code section to check for duplicates in the key field because "remove duplicates was part of my project" and I wanted to make sure...we know what happens when you assume.

# %%
book_list.work_id.value_counts()
book_list.shape

# %%
book_list.work_id.isnull().sum()
book_list.isbn.isnull().sum()
book_list.isbn13.isnull().sum()
book_list.original_publication_year.isnull().sum()
book_list.num_pages.isnull().sum()
book_list.description.isnull().sum()
book_list.genres.isnull().sum()
book_list.reviews_count.isnull().sum()
book_list.text_reviews_count.isnull().sum()
book_list['5_star_ratings'].isnull().sum()
book_list['4_star_ratings'].isnull().sum()
book_list['3_star_ratings'].isnull().sum()
book_list['2_star_ratings'].isnull().sum()
book_list['1_star_ratings'].isnull().sum()
book_list.ratings_count.isnull().sum()
book_list.avg_rating.isnull().sum()
book_list.similar_books.isnull().sum()

# %% [markdown]
# I find it odd that there are so many nulls in isbn and isbn13. ISBNs are to books as SSNs are to natural-born US citizens. Right now it is not worth it to look up all those missing values.
# I can find 18 publication years...that could be useful when curating a reading list. Number of pages would likewise be useful, but right now 730 missing values is not worth figuring out how to find.

# %% [markdown]
# Looking deeper into the anomalies of num_pages...
# * statistics are weird
# * low page books aren't unusual, but after checking a few, they are more than likely incorrect

# %%
book_list.num_pages.describe()
book_list.loc[book_list.num_pages.isnull()==True]

# %% [markdown]
# ## Findings and Action Items
# ### Reviews Table
# * Data type of started_at, read_at and date_added should be changed from int64 to date/time.
# * Data type of review_id, user_id and review_text should be changed from object to string.
# * Significant amount of nulls in started_at, read_at and rating. Recommend eliminating started_at and read_at due to lack of relevance to book recommendation.
# * 3% of rows in rating are null. Propose two options:
#     * Impute the average rating value of 3.8
#     * Replace with N/A or None (eliminates mathematical operations for analysis)
# * Recommend putting less weight on using rating as an input for recommendation or having a null rating handler function
#
# ### Book_List Table
# * isbn and isbn13 should be same type, can change to int or string
# * original_publish_year can be changed from float to date/time
# * num_pages should be changed to int
# * Description can be changed to string
#     * Consider removing the \n coding during transformation
# * Recommendations for nulls
#     * isbn and isbn13 replace with Missing if a test shows that 1% do exist but aren't listed, replace with None or Unknown if 1% cannot be found
#     * Research original publish years and add values
#     * descriptions replace with Missing
#     * num_pages consider how the data will be used in recommendations...using non-numeric replacement disallows mathematical functions, using 0 will skew mathematical results, mean or median may be appropriate
# * Remove image url column

# %% [markdown]
# # Transformation

# %% [markdown]
# ## Null Handling
# Recommendations for nulls
# * isbn and isbn13 replace with Missing if a test shows that 1% do exist but aren't listed, replace with None or Unknown if 1% cannot be found
# * Research original publish years and add values
# * descriptions replace with Missing
# * num_pages consider how the data will be used in recommendations...using non-numeric replacement disallows mathematical functions, using 0 will skew mathematical results, mean or median may be appropriate
#     * 7/31/25: consulted with ChatGPT about automation options to use filtered df info to search IoT for page counts because they do exist. ChatGPT built a Python script to search openlibrary (first) and GoogleBooks (as fallback after many failures) APIs. Only 67 books were still null afterward and manual research took care of those.
# * Significant amount of nulls in started_at, read_at and rating.
#     * Recommend eliminating started_at and read_at due to lack of relevance to book recommendation.
# * 3% of rows in rating are null. Propose two options:
#     * Impute the average rating value of 3.8
#     * Replace with N/A or None (eliminates mathematical operations for analysis)

# %%
reviews.rating.median()
reviews.rating.mean()

# %%
book_list['description']=book_list.description.fillna('Missing')
book_list['num_pages']=book_list.num_pages.fillna(0)
book_list['isbn13']=book_list.isbn.fillna(0) #after discussing with my wingman
book_list.head()
reviews['rating']=reviews.rating.fillna(3.8)
reviews.rating.isnull().sum()
# Out:
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
#     work_id        isbn        isbn13         original_title  \
# 0   2919130  1416534601  9.781417e+12              Nocturnes
# 1  52087333         NaN           NaN              Draw Play
# 2   1649583  1416505520  9.781417e+12  Citizen of the Galaxy
# 3    688299  0060541830  9.780061e+12                  Congo
# 4   3464264  0451528824  9.780452e+12   Anne of Green Gables
#
#                author  original_publication_year  num_pages  \
# 0       John Connolly                     2004.0        0.0
# 1           Tia Lewis                     2016.0        0.0
# 2  Robert A. Heinlein                     1957.0        0.0
# 3    Michael Crichton                     1980.0        0.0
# 4     L.M. Montgomery                     1908.0        0.0
#
#                                          description  \
# 0                                            Missing
# 1  Jake:\nI can't believe my coach assigned me a ...
# 2  In a distant galaxy, the atrocity of slavery w...
# 3  Deep in the African rain forest, near the lege...
# 4  Everyone's favorite redhead, the spunky Anne S...
#
#                                               genres  \
# 0  fiction, fantasy, paranormal, mystery, thrille...
# 1                                   romance, fiction
# 2  fiction, young-adult, fantasy, paranormal, chi...
# 3  fiction, mystery, thriller, crime, fantasy, pa...
# 4  fiction, young-adult, children, history, histo...
#
#                                            image_url  reviews_count  \
# 0  https://s.gr-assets.com/assets/nophoto/book/11...           8820
# 1  https://s.gr-assets.com/assets/nophoto/book/11...           2482
# 2  https://s.gr-assets.com/assets/nophoto/book/11...          16506
# 3  https://s.gr-assets.com/assets/nophoto/book/11...         170916
# 4  https://s.gr-assets.com/assets/nophoto/book/11...         743392
#
#    text_reviews_count  5_star_ratings  4_star_ratings  3_star_ratings  \
# 0                 338            1118            1601            1029
# 1                 204             204             353             274
# 2                 447            3539            4351            2863
# 3                1633           25081           45775           48505
# 4               14586          272952          161856           81578
#
#    2_star_ratings  1_star_ratings  ratings_count  avg_rating similar_books
# 0             190              58           3996         3.9           NaN
# 1              77              29            937         3.7           NaN
# 2             444              53          11250         4.0           NaN
# 3           14001            2926         136288         3.6           NaN
# 4           19933            9099         545418         4.2           NaN
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_36/1070072241.py in <cell line: 0>()
#       3 book_list['num_pages']=book_list.num_pages.fillna(0) #after discussing with my wingman
#       4 book_list.head()
# ----> 5 reviews['rating']=reviews.rating.fillna(3.8)
#       6 reviews.rating.isnull().sum()
#
# NameError: name 'reviews' is not defined

# %% [markdown]
# A-reasearching we go! First up are publication years...

# %%
#book_list.loc[book_list.original_publication_year.isnull()==True]
#book_list.original_publication_year[52]=2016
book_list.loc[52,'original_publication_year']=2016
book_list.loc[52].original_publication_year
book_list.loc[239].original_publication_year #result: nan
book_list.loc[239,'original_publication_year']=2007
book_list.loc[239].original_publication_year #result: 2007 🎉Yay! I'm changing what I want changed!!
book_list.loc[291,'original_publication_year']=2008
book_list.loc[445,'original_publication_year']=2006
book_list.loc[2638,'original_publication_year']=2012
book_list.loc[3105,'original_publication_year']=2012
book_list.loc[3152,'original_publication_year']=2015
book_list.loc[4284,'original_publication_year']=2014
book_list.loc[10630,'original_publication_year']=2016
book_list.loc[11195,'original_publication_year']=2016
book_list.loc[11219,'original_publication_year']=2001
book_list.loc[11237,'original_publication_year']=2016
book_list.loc[11700,'original_publication_year']=2016
book_list.loc[12111,'original_publication_year']=2016
book_list.loc[12118,'original_publication_year']=2013
book_list.loc[12145,'original_publication_year']=2016
book_list.loc[12195,'original_publication_year']=2016
book_list.loc[13235,'original_publication_year']=2016
#book_list.loc[12235]
#book_list.original_publication_year.isnull().sum() #whoops! I had a typo and changed 12235 by mistake to 2016...better check what it should be
#book_list.loc[12235,'original_publication_year']=2011 #crisis averted
#book_list.loc[12235]
# Out:
# 2016.0
# nan
# 2007.0

# %% [markdown]
# Keeping an eye on those last five with missing isbn/isbn13, only one did not have any...it had an ASIN instead
# Replace isbn and isbn13 NaN with "Missing"

# %%
book_list['isbn13']=pd.to_numeric(book_list['isbn13'],errors='coerce').fillna(0).astype('int64').astype('string')#guidance from ChatGPT to force isbn13 to behave
book_list.isbn13.head()
book_list[['isbn','isbn13']]=book_list[['isbn','isbn13']].fillna('Missing')
book_list.isbn.head()
book_list['isbn13']=book_list['isbn13'].replace('0','Missing')
book_list.head()
# Out:
# 0    9781416534600
# 1                0
# 2    9781416505525
# 3    9780060541835
# 4    9780451528827
# Name: isbn13, dtype: string
# 0    1416534601
# 1       Missing
# 2    1416505520
# 3    0060541830
# 4    0451528824
# Name: isbn, dtype: object
#     work_id        isbn         isbn13         original_title  \
# 0   2919130  1416534601  9781416534600              Nocturnes
# 1  52087333     Missing        Missing              Draw Play
# 2   1649583  1416505520  9781416505525  Citizen of the Galaxy
# 3    688299  0060541830  9780060541835                  Congo
# 4   3464264  0451528824  9780451528827   Anne of Green Gables
#
#                author  original_publication_year  num_pages  \
# 0       John Connolly                     2004.0        0.0
# 1           Tia Lewis                     2016.0        0.0
# 2  Robert A. Heinlein                     1957.0        0.0
# 3    Michael Crichton                     1980.0        0.0
# 4     L.M. Montgomery                     1908.0        0.0
#
#                                          description  \
# 0                                            Missing
# 1  Jake:\nI can't believe my coach assigned me a ...
# 2  In a distant galaxy, the atrocity of slavery w...
# 3  Deep in the African rain forest, near the lege...
# 4  Everyone's favorite redhead, the spunky Anne S...
#
#                                               genres  \
# 0  fiction, fantasy, paranormal, mystery, thrille...
# 1                                   romance, fiction
# 2  fiction, young-adult, fantasy, paranormal, chi...
# 3  fiction, mystery, thriller, crime, fantasy, pa...
# 4  fiction, young-adult, children, history, histo...
#
#                                            image_url  reviews_count  \
# 0  https://s.gr-assets.com/assets/nophoto/book/11...           8820
# 1  https://s.gr-assets.com/assets/nophoto/book/11...           2482
# 2  https://s.gr-assets.com/assets/nophoto/book/11...          16506
# 3  https://s.gr-assets.com/assets/nophoto/book/11...         170916
# 4  https://s.gr-assets.com/assets/nophoto/book/11...         743392
#
#    text_reviews_count  5_star_ratings  4_star_ratings  3_star_ratings  \
# 0                 338            1118            1601            1029
# 1                 204             204             353             274
# 2                 447            3539            4351            2863
# 3                1633           25081           45775           48505
# 4               14586          272952          161856           81578
#
#    2_star_ratings  1_star_ratings  ratings_count  avg_rating similar_books
# 0             190              58           3996         3.9           NaN
# 1              77              29            937         3.7           NaN
# 2             444              53          11250         4.0           NaN
# 3           14001            2926         136288         3.6           NaN
# 4           19933            9099         545418         4.2           NaN

# %% [markdown]
# [consulting with ChatGPT about how to update nulls in a column *in situ*](https://chatgpt.com/share/6876aabe-ff4c-8005-b99c-cf045a8c952c)

# %%
#getting a filtered df of only the books without a page count
no_pages=book_list.loc[book_list['num_pages']==0,["original_title","author","original_publication_year","num_pages"]]
no_pages.head()
no_pages.shape
no_pages.to_csv("no_pages.csv",index=False)
no_pages=no_pages.rename(columns={'original_title':'Title'}) #ah, the intricacies of working with AI
no_pages.head()
# Out:
#           original_title              author  original_publication_year  \
# 0              Nocturnes       John Connolly                       2004
# 1              Draw Play           Tia Lewis                       2016
# 2  Citizen of the Galaxy  Robert A. Heinlein                       1957
# 3                  Congo    Michael Crichton                       1980
# 4   Anne of Green Gables     L.M. Montgomery                       1908
#
#    num_pages
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# (730, 4)
#                    Title              author  original_publication_year  \
# 0              Nocturnes       John Connolly                       2004
# 1              Draw Play           Tia Lewis                       2016
# 2  Citizen of the Galaxy  Robert A. Heinlein                       1957
# 3                  Congo    Michael Crichton                       1980
# 4   Anne of Green Gables     L.M. Montgomery                       1908
#
#    num_pages
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0

# %%
yes_pages=pd.read_csv("/kaggle/input/bookdata/filled_pages.csv")
#yes_pages.dtypes
#yes_pages.head() #checking the data 
#yes_pages=yes_pages.drop({'Author','Year','Length','Confidence','Title_Score','Author_Score','Source','OL_Title','OL_Author','Used_Edition_Fallback'},axis=1)
#drop some ballast
#yes_pages.head()
yes_pages.shape
# Out:
# (729, 4)

# %% [markdown]
# Now to merge the good column into the bad df.

# %%
temp=book_list.copy()
temp=temp.rename(columns={'original_title':'Title'})
# Merge df1 with df2
merged_df = pd.merge(temp, yes_pages, on='Title',how='left')
# Check what I've got
#merged_df.head()
#merged_df.loc[merged_df.num_pages==0]
#merged_df.loc[merged_df.num_pages!=0]
# Conditionally assign 'New_Data' to 'Data' where 'New_Data' is not NaN
merged_df['num_pages'] = merged_df['Length'].fillna(merged_df['num_pages'])
#merged_df.head()
merged_df.loc[merged_df.num_pages==0]
# Out:
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
#         work_id     isbn         isbn13              Title  \
# 2472   17305856  Missing  9780983405894    Fated Encounter
# 2608   44681074  Missing        Missing         Royal Date
# 12191   6570040  Missing        Missing  A Dream of Spring
#
#                    author  original_publication_year  num_pages  \
# 2472        J.A. Belfield                       2011        0.0
# 2608        Sariah Wilson                       2015        0.0
# 12191  George R.R. Martin                       2021        0.0
#
#                                              description  \
# 2472   One glimpse. That scent. There. Right there. C...
# 2608   This Cinderella didn't plan on a prince...\nKa...
# 12191  Originally titled "A Time For Wolves". The sev...
#
#                                                   genres  \
# 2472               fantasy, paranormal, romance, fiction
# 2608                       romance, young-adult, fiction
# 12191  fantasy, paranormal, fiction, history, histori...
#
#                                                image_url  ...  4_star_ratings  \
# 2472   https://s.gr-assets.com/assets/nophoto/book/11...  ...              15
# 2608   https://s.gr-assets.com/assets/nophoto/book/11...  ...            1012
# 12191  https://images.gr-assets.com/books/1472364296m...  ...             210
#
#        3_star_ratings  2_star_ratings  1_star_ratings  ratings_count  \
# 2472               13               1               0             51
# 2608              531             162              68           2992
# 12191              68              25              30            917
#
#        avg_rating                                      similar_books  \
# 2472          4.1                                 17931837, 17356438
# 2608          4.1                                           41249989
# 12191         4.4  21905325, 43242921, 23584221, 24064368, 250762...
#
#                    Author    Year Length
# 2472        J.A. Belfield  2011.0    0.0
# 2608                  NaN     NaN    NaN
# 12191  George R.R. Martin     0.0    0.0
#
# [3 rows x 23 columns]

# %%
#[2608] wasn't in my working list so I'll take care of it right here. The other two I could not find.
merged_df.loc[2608,'num_pages']=258
merged_df.loc[merged_df.num_pages==0]
# Out:
#         work_id     isbn         isbn13              Title  \
# 2472   17305856  Missing  9780983405894    Fated Encounter
# 12191   6570040  Missing        Missing  A Dream of Spring
#
#                    author  original_publication_year  num_pages  \
# 2472        J.A. Belfield                       2011        0.0
# 12191  George R.R. Martin                       2021        0.0
#
#                                              description  \
# 2472   One glimpse. That scent. There. Right there. C...
# 12191  Originally titled "A Time For Wolves". The sev...
#
#                                                   genres  \
# 2472               fantasy, paranormal, romance, fiction
# 12191  fantasy, paranormal, fiction, history, histori...
#
#                                                image_url  ...  3_star_ratings  \
# 2472   https://s.gr-assets.com/assets/nophoto/book/11...  ...              13
# 12191  https://images.gr-assets.com/books/1472364296m...  ...              68
#
#        2_star_ratings  1_star_ratings  ratings_count  avg_rating  \
# 2472                1               0             51         4.1
# 12191              25              30            917         4.4
#
#                                            similar_books              Author  \
# 2472                                  17931837, 17356438       J.A. Belfield
# 12191  21905325, 43242921, 23584221, 24064368, 250762...  George R.R. Martin
#
#          Year  Length (2608, num_pages)
# 2472   2011.0     0.0             258.0
# 12191     0.0     0.0             258.0
#
# [2 rows x 24 columns]

# %%
# Drop the unneeded columns and retype num_pages as int
book_list = merged_df.drop({'Author','Year','Length'}, axis=1)
book_list['num_pages']=book_list.num_pages.astype(int)
book_list.dtypes
book_list.head()
# Out:
# work_id                               int64
# isbn                                 object
# isbn13                       string[python]
# Title                                object
# author                               object
# original_publication_year             int64
# num_pages                             int64
# description                          object
# genres                               object
# image_url                            object
# reviews_count                         int64
# text_reviews_count                    int64
# 5_star_ratings                        int64
# 4_star_ratings                        int64
# 3_star_ratings                        int64
# 2_star_ratings                        int64
# 1_star_ratings                        int64
# ratings_count                         int64
# avg_rating                          float64
# similar_books                        object
# (2608, num_pages)                   float64
# dtype: object
#     work_id        isbn         isbn13                  Title  \
# 0   2919130  1416534601  9781416534600              Nocturnes
# 1  52087333     Missing        Missing              Draw Play
# 2   1649583  1416505520  9781416505525  Citizen of the Galaxy
# 3    688299  0060541830  9780060541835                  Congo
# 4   3464264  0451528824  9780451528827   Anne of Green Gables
#
#                author  original_publication_year  num_pages  \
# 0       John Connolly                       2004        497
# 1           Tia Lewis                       2016        258
# 2  Robert A. Heinlein                       1957        290
# 3    Michael Crichton                       1980        466
# 4     L.M. Montgomery                       1908        378
#
#                                          description  \
# 0                                            Missing
# 1  Jake:\nI can't believe my coach assigned me a ...
# 2  In a distant galaxy, the atrocity of slavery w...
# 3  Deep in the African rain forest, near the lege...
# 4  Everyone's favorite redhead, the spunky Anne S...
#
#                                               genres  \
# 0  fiction, fantasy, paranormal, mystery, thrille...
# 1                                   romance, fiction
# 2  fiction, young-adult, fantasy, paranormal, chi...
# 3  fiction, mystery, thriller, crime, fantasy, pa...
# 4  fiction, young-adult, children, history, histo...
#
#                                            image_url  ...  text_reviews_count  \
# 0  https://s.gr-assets.com/assets/nophoto/book/11...  ...                 338
# 1  https://s.gr-assets.com/assets/nophoto/book/11...  ...                 204
# 2  https://s.gr-assets.com/assets/nophoto/book/11...  ...                 447
# 3  https://s.gr-assets.com/assets/nophoto/book/11...  ...                1633
# 4  https://s.gr-assets.com/assets/nophoto/book/11...  ...               14586
#
#    5_star_ratings  4_star_ratings  3_star_ratings  2_star_ratings  \
# 0            1118            1601            1029             190
# 1             204             353             274              77
# 2            3539            4351            2863             444
# 3           25081           45775           48505           14001
# 4          272952          161856           81578           19933
#
#    1_star_ratings  ratings_count  avg_rating  similar_books (2608, num_pages)
# 0              58           3996         3.9            NaN             258.0
# 1              29            937         3.7            NaN             258.0
# 2              53          11250         4.0            NaN             258.0
# 3            2926         136288         3.6            NaN             258.0
# 4            9099         545418         4.2            NaN             258.0
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Data Types

# %% [markdown]
# * Data type of started_at, read_at and date_added should be changed from int64 to date/time.
# * Data type of review_id, user_id and review_text should be changed from object to string.
# * isbn and isbn13 should be same type, can change to int or string
# * original_publish_year can be changed from float to date/time
# * num_pages should be changed to int
# * Description can be changed to string
#     * Consider removing the \n coding during transformation

# %%
reviews.review_id.astype("string")
reviews.review_text.astype("string")

# %% [markdown]
# "One peculiarity to keep in mind (and on display very clearly here) is that columns consisting entirely of strings do not get their own type; they are instead given the object type."
# 🤦🏼‍♀️Read Mel

# %%
#book_list.isbn.astype(int) #ValueError: cannot convert float NaN to integer
#book_list.isbn.astype(float) #ValueError: could not convert string to float: '080075963X' Fun fact-ISBN check digits are base eleven so they include digits 0-9 and 'X'
#book_list.isbn13.astype(float)
book_list.isbn.astype("string")
#for consistency's sake and because there will be no need for math on ISBN13, let's make it a string too
book_list.isbn13.astype("string")
# Out:
# 0        1416534601
# 1           Missing
# 2        1416505520
# 3        0060541830
# 4        0451528824
#             ...
# 13520       Missing
# 13521       Missing
# 13522       Missing
# 13523       Missing
# 13524       Missing
# Name: isbn, Length: 13525, dtype: string
# 0        9781416534600
# 1              Missing
# 2        9781416505525
# 3        9780060541835
# 4        9780451528827
#              ...
# 13520          Missing
# 13521          Missing
# 13522          Missing
# 13523          Missing
# 13524          Missing
# Name: isbn13, Length: 13525, dtype: string

# %%
#book_list.num_pages.astype(int) #IntCastingNaNError: Cannot convert non-finite values (NA or inf) to integer
#need to decide what to do about the nulls...for now change them all to 0 because there are no 0 entries > 1 was the min
#book_list.loc[book_list.num_pages.isnull()] before ChatGPT discussion
book_list['num_pages']=book_list.num_pages.astype(int)
book_list['original_publication_year']=book_list.original_publication_year.astype(int)
book_list.dtypes
# Out:
# work_id                               int64
# isbn                                 object
# isbn13                       string[python]
# Title                                object
# author                               object
# original_publication_year             int64
# num_pages                             int64
# description                          object
# genres                               object
# image_url                            object
# reviews_count                         int64
# text_reviews_count                    int64
# 5_star_ratings                        int64
# 4_star_ratings                        int64
# 3_star_ratings                        int64
# 2_star_ratings                        int64
# 1_star_ratings                        int64
# ratings_count                         int64
# avg_rating                          float64
# similar_books                        object
# (2608, num_pages)                   float64
# dtype: object

# %% [markdown]
# Datetime experimentation...

# %%
#temp_year=pd.DataFrame({'Year':book_list.original_publication_year.copy()})
#temp_year.Year.astype(str)
#pd.to_datetime('Year',yearfirst=True,format="mixed")

# %% [markdown]
# We are throwing a fit because we do not recognize a year on its own to parse as a date. There isn't a good reason except for "but it's time!" to convert it from an int, so I'm crawling out of this rabbit hole.

# %% [markdown]
# ## Standardization
# Inspect what you expect and expect what you inspect

# %%
#reviews.head()
#reviews.loc[reviews.started_at.notnull()]
reviews=reviews.rename(columns={'started_at': 'started','read_at':'finished','date_added':'review_added','review_text': 'review','n_votes': 'num_votes','n_comments':'num_comments'})

# %% [markdown]
# I made my app in Streamlit with unclean data and have renaming in the app. For the sake of less headaches right now, I am going to export my cleaner book_list at this point. I can always come back later and get my migraine.

# %%
book_list.to_csv("cleaned_works.csv",index=False)

# %%
book_list.head()
book_list=book_list.drop('image_url',axis=1)
reviews=reviews.drop(['started','finished'],axis=1)

book_list=book_list.rename(columns={'original_title':'title','reviews_count':'total_reviews','text_reviews_count':'num_written_reviews','5_star_ratings':'5stars','4_star_ratings':'4stars','3_star_ratings':'3stars','2_star_ratings':'2stars','1_star_ratings':'1star','ratings_count':'total_ratings'})
book_list.head()
# Out:
#     work_id        isbn         isbn13         original_title  \
# 0   2919130  1416534601  9781416534600              Nocturnes
# 1  52087333     Missing        Missing              Draw Play
# 2   1649583  1416505520  9781416505525  Citizen of the Galaxy
# 3    688299  0060541830  9780060541835                  Congo
# 4   3464264  0451528824  9780451528827   Anne of Green Gables
#
#                author  original_publication_year  num_pages  \
# 0       John Connolly                       2004          0
# 1           Tia Lewis                       2016          0
# 2  Robert A. Heinlein                       1957          0
# 3    Michael Crichton                       1980          0
# 4     L.M. Montgomery                       1908          0
#
#                                          description  \
# 0                                            Missing
# 1  Jake:\nI can't believe my coach assigned me a ...
# 2  In a distant galaxy, the atrocity of slavery w...
# 3  Deep in the African rain forest, near the lege...
# 4  Everyone's favorite redhead, the spunky Anne S...
#
#                                               genres  \
# 0  fiction, fantasy, paranormal, mystery, thrille...
# 1                                   romance, fiction
# 2  fiction, young-adult, fantasy, paranormal, chi...
# 3  fiction, mystery, thriller, crime, fantasy, pa...
# 4  fiction, young-adult, children, history, histo...
#
#                                            image_url  reviews_count  \
# 0  https://s.gr-assets.com/assets/nophoto/book/11...           8820
# 1  https://s.gr-assets.com/assets/nophoto/book/11...           2482
# 2  https://s.gr-assets.com/assets/nophoto/book/11...          16506
# 3  https://s.gr-assets.com/assets/nophoto/book/11...         170916
# 4  https://s.gr-assets.com/assets/nophoto/book/11...         743392
#
#    text_reviews_count  5_star_ratings  4_star_ratings  3_star_ratings  \
# 0                 338            1118            1601            1029
# 1                 204             204             353             274
# 2                 447            3539            4351            2863
# 3                1633           25081           45775           48505
# 4               14586          272952          161856           81578
#
#    2_star_ratings  1_star_ratings  ratings_count  avg_rating similar_books
# 0             190              58           3996         3.9           NaN
# 1              77              29            937         3.7           NaN
# 2             444              53          11250         4.0           NaN
# 3           14001            2926         136288         3.6           NaN
# 4           19933            9099         545418         4.2           NaN
#     work_id        isbn         isbn13                  title  \
# 0   2919130  1416534601  9781416534600              Nocturnes
# 1  52087333     Missing        Missing              Draw Play
# 2   1649583  1416505520  9781416505525  Citizen of the Galaxy
# 3    688299  0060541830  9780060541835                  Congo
# 4   3464264  0451528824  9780451528827   Anne of Green Gables
#
#                author  original_publication_year  num_pages  \
# 0       John Connolly                       2004          0
# 1           Tia Lewis                       2016          0
# 2  Robert A. Heinlein                       1957          0
# 3    Michael Crichton                       1980          0
# 4     L.M. Montgomery                       1908          0
#
#                                          description  \
# 0                                            Missing
# 1  Jake:\nI can't believe my coach assigned me a ...
# 2  In a distant galaxy, the atrocity of slavery w...
# 3  Deep in the African rain forest, near the lege...
# 4  Everyone's favorite redhead, the spunky Anne S...
#
#                                               genres  total_reviews  \
# 0  fiction, fantasy, paranormal, mystery, thrille...           8820
# 1                                   romance, fiction           2482
# 2  fiction, young-adult, fantasy, paranormal, chi...          16506
# 3  fiction, mystery, thriller, crime, fantasy, pa...         170916
# 4  fiction, young-adult, children, history, histo...         743392
#
#    num_written_reviews  5stars  4stars  3stars  2stars  1star  total_ratings  \
# 0                  338    1118    1601    1029     190     58           3996
# 1                  204     204     353     274      77     29            937
# 2                  447    3539    4351    2863     444     53          11250
# 3                 1633   25081   45775   48505   14001   2926         136288
# 4                14586  272952  161856   81578   19933   9099         545418
#
#    avg_rating similar_books
# 0         3.9           NaN
# 1         3.7           NaN
# 2         4.0           NaN
# 3         3.6           NaN
# 4         4.2           NaN

# %% [markdown]
# ## Normalization

# %%
#temp=book_list.copy() before I break anything, let's experiment on a copy
book_list['description']=book_list['description'].str.strip()
book_list['title']=book_list['title'].str.strip()
book_list['author']=book_list['author'].str.strip()
book_list['genres']=book_list['genres'].str.strip()
book_list.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'title'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_36/729720723.py in <cell line: 0>()
#       1 #temp=book_list.copy() before I break anything, let's experiment on a copy
#       2 book_list['description']=book_list['description'].str.strip()
# ----> 3 book_list['title']=book_list['title'].str.strip()
#       4 book_list['author']=book_list['author'].str.strip()
#       5 book_list['genres']=book_list['genres'].str.strip()
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'title'

# %% [markdown]
# Using a temp df again to experiment with 'extract' to get the ".0" off the end of isbn13

# %%
#temp=book_list.copy()
#temp['isbn13']=temp.isbn13.replace('Missing',0)
#temp.isbn13.astype('int64') #python is refusing to convert the ISBN13 to a string, it only treats it as a float

#temp.isbn13.str.extract(r"(['.0'])")
#temp.isbn13.str.rsplit('.',expand=True)
#temp['isbn13']=temp['isbn13'].str[:-2]
#temp.loc[2]
#temp['isbn13']=temp['isbn13'].str.rstrip()
#temp.loc[2]
#temp['isbn13'].apply(str).value_counts()
#temp['isbn13'].apply(lambda x:type(x)).value_counts()
#temp.isbn13.dtype
#temp['isbn13'].apply(lambda x:str(x))
#temp['isbn13'].apply(lambda x:f"{x:.0f})
#temp['isbn13']=temp.isbn13.replace(0,'Missing') #does not replace

#print(temp['isbn13'])

# %% [markdown]
# **WTF Mate?**
# In the code cell above, I was having issues. Looking back, I think I screwed everything up by converting the float directly to string without the int intermediary. The data was carrying a '.0' that it refused to get rid of despite all my efforts. I researched the internet on my own and even created a [separate testing notebook](https://www.kaggle.com/code/melisandefritzsche/testing) to use for testing concepts and troubleshooting. At a loss, I consulted with my AI partner.
# [ChatGPT consultation](https://chatgpt.com/share/6879014b-ffe0-8005-9a77-cf04c80b590f)
# *Solution*
# I implemented the solution up in the [null handling](https://www.kaggle.com/code/melisandefritzsche/bookshelf-challenge/edit/run/250847672#Null-Handling) section.

# %%
book_list=book_list.set_index('work_id')
reviews=reviews.set_index('review_id')

# %% [markdown]
# ## Splitting and Extracting

# %% [markdown]
# separating the genre lists into individual genres will assist in grouping

# %%
genres=book_list.copy()
genres.shape
book_list.head()
#genre_split=genres['genres'].str.split(',',expand=True)
#genre_split
#genre_split=genres['genres'].str.split(',').explode('genres').reset_index                                                
#genre_split
# Out:
# (13525, 19)
#     work_id        isbn         isbn13                  title  \
# 0   2919130  1416534601  9781416534600              Nocturnes
# 1  52087333     Missing        Missing              Draw Play
# 2   1649583  1416505520  9781416505525  Citizen of the Galaxy
# 3    688299  0060541830  9780060541835                  Congo
# 4   3464264  0451528824  9780451528827   Anne of Green Gables
#
#                author  original_publication_year  num_pages  \
# 0       John Connolly                       2004          0
# 1           Tia Lewis                       2016          0
# 2  Robert A. Heinlein                       1957          0
# 3    Michael Crichton                       1980          0
# 4     L.M. Montgomery                       1908          0
#
#                                          description  \
# 0                                            Missing
# 1  Jake:\nI can't believe my coach assigned me a ...
# 2  In a distant galaxy, the atrocity of slavery w...
# 3  Deep in the African rain forest, near the lege...
# 4  Everyone's favorite redhead, the spunky Anne S...
#
#                                               genres  total_reviews  \
# 0  fiction, fantasy, paranormal, mystery, thrille...           8820
# 1                                   romance, fiction           2482
# 2  fiction, young-adult, fantasy, paranormal, chi...          16506
# 3  fiction, mystery, thriller, crime, fantasy, pa...         170916
# 4  fiction, young-adult, children, history, histo...         743392
#
#    num_written_reviews  5stars  4stars  3stars  2stars  1star  total_ratings  \
# 0                  338    1118    1601    1029     190     58           3996
# 1                  204     204     353     274      77     29            937
# 2                  447    3539    4351    2863     444     53          11250
# 3                 1633   25081   45775   48505   14001   2926         136288
# 4                14586  272952  161856   81578   19933   9099         545418
#
#    avg_rating similar_books
# 0         3.9           NaN
# 1         3.7           NaN
# 2         4.0           NaN
# 3         3.6           NaN
# 4         4.2           NaN

# %% [markdown]
# I am going to try to insert the unexpanded list version of the string into the column using replace and then explode it

# %%
genres['genres']=genres['genres'].str.split(',')
genres.head()
# Out:
#     work_id        isbn         isbn13                  title  \
# 0   2919130  1416534601  9781416534600              Nocturnes
# 1  52087333     Missing        Missing              Draw Play
# 2   1649583  1416505520  9781416505525  Citizen of the Galaxy
# 3    688299  0060541830  9780060541835                  Congo
# 4   3464264  0451528824  9780451528827   Anne of Green Gables
#
#                author  original_publication_year  num_pages  \
# 0       John Connolly                       2004          0
# 1           Tia Lewis                       2016          0
# 2  Robert A. Heinlein                       1957          0
# 3    Michael Crichton                       1980          0
# 4     L.M. Montgomery                       1908          0
#
#                                          description  \
# 0                                            Missing
# 1  Jake:\nI can't believe my coach assigned me a ...
# 2  In a distant galaxy, the atrocity of slavery w...
# 3  Deep in the African rain forest, near the lege...
# 4  Everyone's favorite redhead, the spunky Anne S...
#
#                                               genres  total_reviews  \
# 0  [fiction,  fantasy,  paranormal,  mystery,  th...           8820
# 1                                [romance,  fiction]           2482
# 2  [fiction,  young-adult,  fantasy,  paranormal,...          16506
# 3  [fiction,  mystery,  thriller,  crime,  fantas...         170916
# 4  [fiction,  young-adult,  children,  history,  ...         743392
#
#    num_written_reviews  5stars  4stars  3stars  2stars  1star  total_ratings  \
# 0                  338    1118    1601    1029     190     58           3996
# 1                  204     204     353     274      77     29            937
# 2                  447    3539    4351    2863     444     53          11250
# 3                 1633   25081   45775   48505   14001   2926         136288
# 4                14586  272952  161856   81578   19933   9099         545418
#
#    avg_rating similar_books
# 0         3.9           NaN
# 1         3.7           NaN
# 2         4.0           NaN
# 3         3.6           NaN
# 4         4.2           NaN

# %%
genres_spl=genres.explode('genres')
genres_spl
# Out:
#         work_id        isbn         isbn13                    title  \
# 0       2919130  1416534601  9781416534600                Nocturnes
# 0       2919130  1416534601  9781416534600                Nocturnes
# 0       2919130  1416534601  9781416534600                Nocturnes
# 0       2919130  1416534601  9781416534600                Nocturnes
# 0       2919130  1416534601  9781416534600                Nocturnes
# ...         ...         ...            ...                      ...
# 13523  56412634     Missing        Missing  The Bet (Player Series)
# 13523  56412634     Missing        Missing  The Bet (Player Series)
# 13523  56412634     Missing        Missing  The Bet (Player Series)
# 13524  51402505     Missing        Missing             Danced Close
# 13524  51402505     Missing        Missing             Danced Close
#
#                  author  original_publication_year  num_pages  \
# 0         John Connolly                       2004          0
# 0         John Connolly                       2004          0
# 0         John Connolly                       2004          0
# 0         John Connolly                       2004          0
# 0         John Connolly                       2004          0
# ...                 ...                        ...        ...
# 13523  Elizabeth Hayley                       2017        274
# 13523  Elizabeth Hayley                       2017        274
# 13523  Elizabeth Hayley                       2017        274
# 13524   Annabeth Albert                       2017        132
# 13524   Annabeth Albert                       2017        132
#
#                                              description        genres  \
# 0                                                Missing       fiction
# 0                                                Missing       fantasy
# 0                                                Missing    paranormal
# 0                                                Missing       mystery
# 0                                                Missing      thriller
# ...                                                  ...           ...
# 13523  Jace "the Jet" Benning is a legend on the foot...       romance
# 13523  Jace "the Jet" Benning is a legend on the foot...       fiction
# 13523  Jace "the Jet" Benning is a legend on the foot...   young-adult
# 13524  Portland, Oregon, is one of the hottest cities...       romance
# 13524  Portland, Oregon, is one of the hottest cities...       fiction
#
#        total_reviews  num_written_reviews  5stars  4stars  3stars  2stars  \
# 0               8820                  338    1118    1601    1029     190
# 0               8820                  338    1118    1601    1029     190
# 0               8820                  338    1118    1601    1029     190
# 0               8820                  338    1118    1601    1029     190
# 0               8820                  338    1118    1601    1029     190
# ...              ...                  ...     ...     ...     ...     ...
# 13523            334                   64      24      42      26      10
# 13523            334                   64      24      42      26      10
# 13523            334                   64      24      42      26      10
# 13524            935                  131     107     207     133      25
# 13524            935                  131     107     207     133      25
#
#        1star  total_ratings  avg_rating similar_books
# 0         58           3996         3.9           NaN
# 0         58           3996         3.9           NaN
# 0         58           3996         3.9           NaN
# 0         58           3996         3.9           NaN
# 0         58           3996         3.9           NaN
# ...      ...            ...         ...           ...
# 13523      5            107         3.7           NaN
# 13523      5            107         3.7           NaN
# 13523      5            107         3.7           NaN
# 13524      3            475         3.8           NaN
# 13524      3            475         3.8           NaN
#
# [79391 rows x 19 columns]

# %% [markdown]
# 🤩**I WIN!**

# %%
genres_spl.genres.value_counts()#checking for duplicates
genres_spl['genres']=genres_spl.genres.str.strip() #previously did not have the genres_spl['genres']=...learning curve observation-I need to get used to syntax for Python just doing a thing versus Pythong doing the thing and keeping it done
#genres_spl.reindex()
#genres_spl.head()
genres_spl.groupby('genres').count().sort_values(by='title',ascending=False)
# Out:
# genres
#  fiction               10095
#  paranormal             7407
#  romance                6805
#  thriller               6607
#  crime                  6607
#  mystery                5587
#  young-adult            4151
#  fantasy                4070
#  biography              3954
#  historical fiction     3954
#  history                3525
# fantasy                 3337
# fiction                 3092
# romance                 2450
# young-adult             2299
#  children               1206
# mystery                 1020
#  graphic                 961
# comics                   512
#  comics                  449
# history                  429
#  non-fiction             326
# non-fiction              275
#  poetry                  162
# children                  91
# poetry                    20
# Name: count, dtype: int64
#                     work_id   isbn  isbn13  title  author  \
# genres
# fiction               13187  13187   13187  13187   13187
# romance                9255   9255    9255   9255    9255
# fantasy                7407   7407    7407   7407    7407
# paranormal             7407   7407    7407   7407    7407
# crime                  6607   6607    6607   6607    6607
# mystery                6607   6607    6607   6607    6607
# thriller               6607   6607    6607   6607    6607
# young-adult            6450   6450    6450   6450    6450
# biography              3954   3954    3954   3954    3954
# historical fiction     3954   3954    3954   3954    3954
# history                3954   3954    3954   3954    3954
# children               1297   1297    1297   1297    1297
# comics                  961    961     961    961     961
# graphic                 961    961     961    961     961
# non-fiction             601    601     601    601     601
# poetry                  182    182     182    182     182
#
#                     original_publication_year  num_pages  description  \
# genres
# fiction                                 13187      13187        13187
# romance                                  9255       9255         9255
# fantasy                                  7407       7407         7407
# paranormal                               7407       7407         7407
# crime                                    6607       6607         6607
# mystery                                  6607       6607         6607
# thriller                                 6607       6607         6607
# young-adult                              6450       6450         6450
# biography                                3954       3954         3954
# historical fiction                       3954       3954         3954
# history                                  3954       3954         3954
# children                                 1297       1297         1297
# comics                                    961        961          961
# graphic                                   961        961          961
# non-fiction                               601        601          601
# poetry                                    182        182          182
#
#                     total_reviews  num_written_reviews  5stars  4stars  \
# genres
# fiction                     13187                13187   13187   13187
# romance                      9255                 9255    9255    9255
# fantasy                      7407                 7407    7407    7407
# paranormal                   7407                 7407    7407    7407
# crime                        6607                 6607    6607    6607
# mystery                      6607                 6607    6607    6607
# thriller                     6607                 6607    6607    6607
# young-adult                  6450                 6450    6450    6450
# biography                    3954                 3954    3954    3954
# historical fiction           3954                 3954    3954    3954
# history                      3954                 3954    3954    3954
# children                     1297                 1297    1297    1297
# comics                        961                  961     961     961
# graphic                       961                  961     961     961
# non-fiction                   601                  601     601     601
# poetry                        182                  182     182     182
#
#                     3stars  2stars  1star  total_ratings  avg_rating  \
# genres
# fiction              13187   13187  13187          13187       13187
# romance               9255    9255   9255           9255        9255
# fantasy               7407    7407   7407           7407        7407
# paranormal            7407    7407   7407           7407        7407
# crime                 6607    6607   6607           6607        6607
# mystery               6607    6607   6607           6607        6607
# thriller              6607    6607   6607           6607        6607
# young-adult           6450    6450   6450           6450        6450
# biography             3954    3954   3954           3954        3954
# historical fiction    3954    3954   3954           3954        3954
# history               3954    3954   3954           3954        3954
# children              1297    1297   1297           1297        1297
# comics                 961     961    961            961         961
# graphic                961     961    961            961         961
# non-fiction            601     601    601            601         601
# poetry                 182     182    182            182         182
#
#                     similar_books
# genres
# fiction                     10820
# romance                      8053
# fantasy                      6318
# paranormal                   6318
# crime                        5471
# mystery                      5471
# thriller                     5471
# young-adult                  5553
# biography                    3051
# historical fiction           3051
# history                      3051
# children                      973
# comics                        664
# graphic                       664
# non-fiction                   268
# poetry                        109

# %%
#genres_spl=genres_spl.set_index('work_id') #after adding the index set to book_list, this is unneccesary
genres_spl.to_csv('genre_split.csv',index=False)

# %% [markdown]
# Just in case for filtering (and for coding practice) I am going to split the author field into first and last name as well.

# %%
temp=book_list.copy()
temp1=temp.author.str.rsplit(' ',n=1,expand=True) #I did something last time -I accidentally undid all my previous work- and inserted the new columns into the original list so I am being redundant as a form of caution
temp1.head()
temp.head()
author_spl=temp
author_spl.insert(4,'first_name',temp1[0])
author_spl.insert(5,'last_name',temp1[1])
author_spl

# %%
#author_spl.dtypes
#author_spl.original_publication_year.astype(int)
author_spl=author_spl.rename(columns={'original_publication_year':'year'})

# %%
#author_pl=author_spl.set_index('work_id')

# %% [markdown]
# *From Testing*
#
# Conclusion: Steps to Take for Implementation
#
# 1. Replace original column in df with split column similar_split=books.similar_books.str.split(', ').apply(lambda x:[int(n) for n in x])
# 2. Use filtering/condition to pull a row...most likely a title... and assign to a variable JP=similar_split.loc[books.original_title == 'Jurassic Park']
# 3. Run the index selection books.loc[books.work_id.isin(JP.iloc[0])]
#
# ***Important Notes***
#
# - step one will use the df['column']= for assignment
# - step two will need a generic variable like 'row' and the == will be in a variable as well (like 'title')
# - step three will have updated variable but iloc index will still be 0

# %%
book_list['similar_books']=book_list.similar_books.str.split(', ').apply(lambda x:[int(n) for n in x])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_36/285434345.py in <cell line: 0>()
# ----> 1 book_list['similar_books']=book_list.similar_books.str.split(', ').apply(lambda x:[int(n) for n in x])
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4922             args=args,
#    4923             kwargs=kwargs,
# -> 4924         ).apply()
#    4925
#    4926     def _reindex_indexer(
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/apply.py in apply(self)
#    1425
#    1426         # self.func is Callable
# -> 1427         return self.apply_standard()
#    1428
#    1429     def agg(self):
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/apply.py in apply_standard(self)
#    1505         #  Categorical (GH51645).
#    1506         action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507         mapped = obj._map_values(
#    1508             mapper=curried, na_action=action, convert=self.convert_dtype
#    1509         )
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/base.py in _map_values(self, mapper, na_action, convert)
#     919             return arr.map(mapper, na_action=na_action)
#     920
# --> 921         return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#     922
#     923     @final
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/algorithms.py in map_array(arr, mapper, na_action, convert)
#    1741     values = arr.astype(object, copy=False)
#    1742     if na_action is None:
# -> 1743         return lib.map_infer(values, mapper, convert=convert)
#    1744     else:
#    1745         return lib.map_infer_mask(
#
# lib.pyx in pandas._libs.lib.map_infer()
#
# /tmp/ipykernel_36/285434345.py in <lambda>(x)
# ----> 1 book_list['similar_books']=book_list.similar_books.str.split(', ').apply(lambda x:[int(n) for n in x])
#
# TypeError: 'float' object is not iterable

# %% [markdown]
# ## Merging and Joining

# %%
#book_list=book_list.set_index('work_id')
#reviews=reviews.set_index('work_id')

#reviews.groupby('work_id').count()
#all_data.head()
#reviews.head()

# %% [markdown]
# *Line in the Sand*
# I fully admit that this is not the most efficient way to do things, but my lack of experience with Python and non-math-related analysis goals (I'm curating a book list so to my mind that basically means I'm going to be filtering and sorting. As opposed to giving statistical descriptions or predicting stuff.)
# Anyway, I am stopping here with five total data frames to use.
# 1. all_data - everything joined together
# 2. book_list - just the book information
# 3. reviews - just the review information
# 4. genres_spl - table with all genres split out
# 5. author_spl - table with authors' first and last names split

# %% [markdown]
# # Analysis

# %% [markdown]
# ## Functions
#
# This whole "build a tool" thing has me a bit confused. I am thinking that I will have a Q&A (not NLP) where I obtain information from the user and then spit out their result. Therefore, I will need helper function to take particular actions like filtering. I should probably define the functionality so that my scope is clear.
#
# * Get how many books the user wants on the list per this query.
# * "Surprise Me!": random number generator to pick books by their work_id
# * Get preferences - fiction/non-fiction, author, genre
# * Filters

# %%
def get_num_books():
    '''
    Function prints a question requesting a total number of books to be curated.
    Returns an integer value less than 13,524.
    '''
    print('How many books would you like on your reading list?')
    while True:
        num_books = input('Enter a number less than 13,525: ')
        try:
            num_books = int(num_books) #check for string or float inputs
        except ValueError:
            print('Please enter a numeric whole number less than 13,525.')
            continue  # Try again
    
        
        if 0 < num_books < 13525: #check that value is in correct range
            break  
        else:
            print('Enter a whole number between 1 and 13,524.')
    
get_num_books()
# Out:
# How many books would you like on your reading list?
# Enter a number less than 13,525: two
# Enter a numeric whole number less than 13,525: -8
# Enter a number less than 13,525: 0
# Enter a whole number between 1 and 13,524: 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_36/2726116119.py in <cell line: 0>()
#      18
#      19
# ---> 20 get_num_books()
#
# /tmp/ipykernel_36/2726116119.py in get_num_books()
#       6     print('How many books would you like on your reading list?')
#       7     while True:
# ----> 8         num_books=input('Enter a number less than 13,525:')
#       9         try:
#      10             num_books = int(num_books)
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
# Enter a number less than 13,525: 2

# %%
def surprise_me(int num_books):
    '''
    Function expects integer value for book list amount.
    Returns a random sample of k amount from dataframe rows range. List is meant to be used to locate rows in full book_list dataframe.
    '''
    reading_list=random.sample(range(0,13525),k=(num_books))
    return reading_list

surprise_me(5)

# %%
books=surprise_me(3)
temp=book_list.sort_values(by='total_reviews',ascending=False)
print('SURPRISE!! Happy reading!')
temp.iloc[books,lambda temp:[2,3,6,7]]

# %% [markdown]
# Take *that*, Python! 😤

# %%
book_list.sort_values(by='total_reviews',ascending=False) #This is how I'd sort my temp list if it were cleaned up and everything. Every time I go back and rerun my code I wind up breaking something so...

# %%
def get_sort():
    '''
    Function asks for user sorting inputs, currently author's name and genre.
    Returns rows meeting both criteria.
    '''
    author=input("Favorite author?")
    genre=input("Favorite genre?")
    
    return book_list.loc[(book_list.author == author) & (book_list['genres'].str.contains(genre))]

get_sort()

# %%
def get_similar(title):
    '''Function accepts a string of book title. The cell in the dataframe containing the list of similar books for
    title is stored in a variable. 
    Function returns a dataframe containing information for similar books found.'''
    
    similar_list=book_list.loc(book_list.title == title)
    if similar_list.isnull()== True:
        print("Sorry, there are no similar book suggestions. 😔")
    else:
        return book_list.loc[book_list.work_id.isin(similar_list.iloc[0])]
    #or print("Sorry, there are no similar book suggestions." if similar_list.isnull() == True else book_list.loc[book_list.work_id.isin(similar_list.iloc[0])])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_36/169670211.py in <cell line: 0>()
#      11     #or print("Sorry, there are no similar book suggestions." if similar_list.isnull() == True else book_list.loc[book_list.work_id.isin(similar_list.iloc[0])])
#      12
# ---> 13 get_similar("Jurassic Park")
#
# /tmp/ipykernel_36/169670211.py in get_similar(title)
#       4     Function returns a dataframe containing information for similar books found.'''
#       5
# ----> 6     similar_list=book_list.loc(book_list.original_title == title)
#       7     if similar_list.isnull()== True:
#       8         print("Sorry, there are no similar book suggestions. 😔")
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexing.py in __call__(self, axis)
#     736
#     737         if axis is not None:
# --> 738             axis_int_none = self.obj._get_axis_number(axis)
#     739         else:
#     740             axis_int_none = axis
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in _get_axis_number(cls, axis)
#     574     def _get_axis_number(cls, axis: Axis) -> AxisInt:
#     575         try:
# --> 576             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     577         except KeyError:
#     578             raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#
# TypeError: unhashable type: 'Series'

# %% [markdown]
# ## Visualization in Python
# Exploring what matplotlib has to offer. Also, instead of stumbling about, I took the Kaggle Data Visualization course and learned about seaborn.

# %%
genres_spl.sort_values(by='total_ratings',ascending=False)

# %%
sns.scatterplot(x='avg_rating',y='total_reviews',data=genres_spl,hue='genres')
plt.title('Average Rating by Genre')
plt.xlabel('Avg Rating')
plt.ylabel('Total Reviews')
plt.legend(loc='upper right',bbox_to_anchor=(1.35,1))
#researched the interwebs and copied but edited
def M_formatter(x, pos):
    """The function formats the tick labels to display in millions."""
    return f'{x / 1_000_000:.1f}M'
plt.gca().yaxis.set_major_formatter(ticker.FuncFormatter(M_formatter))

# %% [markdown]
# Huh. Looks like romance and crime/thriller get reviewed the most and get reviewed highly on average. Young adult and fiction are highest rated even with less overall reviews. That tracks.

# %%
sns.scatterplot(x='avg_rating',y='ratings_count',data=genres_spl,hue='genres')
plt.title('Average Rating by Genre')
plt.xlabel('Avg Rating')
plt.ylabel('Total Reviews')
plt.legend(loc='upper right',bbox_to_anchor=(1.35,1))
#researched the interwebs and copied but edited
def M_formatter(x, pos):
    """The function formats the tick labels to display in millions."""
    return f'{x / 1_000_000:.1f}M'
plt.gca().yaxis.set_major_formatter(ticker.FuncFormatter(M_formatter))

# %%
sns.barplot(x=book_list.avg_rating,y=book_list.num_pages)

# %%
sns.histplot(x=book_list.avg_rating,y=book_list.num_pages)
